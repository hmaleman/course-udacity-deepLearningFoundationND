# %% [markdown]
# ## Exercice 2
# **Linear Regression**: One independent variable and one related dependent variable (prediction).
#
# Use LinearRegression to predict Life expectancy based on Body Mass Index.

# %%
# TODO: Add import statements
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Assign the dataframe to this variable.
# TODO: Load the data
bmi_life_data = pd.read_csv('bmi_and_life_expectancy.csv')
bmi_life_data
# Out:
#                     Country  Life expectancy       BMI
# 0               Afghanistan             52.8  20.62058
# 1                   Albania             76.8  26.44657
# 2                   Algeria             75.5  24.59620
# 3                   Andorra             84.6  27.63048
# 4                    Angola             56.7  22.25083
# 5                   Armenia             72.3  25.35542
# 6                 Australia             81.6  27.56373
# 7                   Austria             80.4  26.46741
# 8                Azerbaijan             69.2  25.65117
# 9                   Bahamas             72.2  27.24594
# 10               Bangladesh             68.3  20.39742
# 11                 Barbados             75.3  26.38439
# 12                  Belarus             70.0  26.16443
# 13                  Belgium             79.6  26.75915
# 14                   Belize             70.7  27.02255
# 15                    Benin             59.7  22.41835
# ...

# %%
x_values = bmi_life_data[['BMI']]
y_values = bmi_life_data[['Life expectancy']]

plt.scatter(x_values, y_values)
plt.show()

# %%
# Make and fit the linear regression model
# TODO: Fit the model and Assign it to bmi_life_model
bmi_life_model = LinearRegression()
bmi_life_model.fit(x_values, y_values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Visualize the built regression model output
plt.plot(x_values, bmi_life_model.predict(x_values))
plt.show()

# %%
# Visualize both, input Body weigth and LinearRegression predition
plt.scatter(x_values, y_values)
plt.plot(x_values, bmi_life_model.predict(x_values))
plt.show()

# %%
# Mak a prediction using the model
# TODO: Predict life expectancy for a BMI value of 21.07931
laos_life_exp = bmi_life_model.predict(21.07931)
laos_life_exp
# Out:
# array([[ 60.31564716]])

# %% [markdown]
# **Extra Pandas fetch example**
#
# http://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas

# %%
bmi_life_data.loc[bmi_life_data['Country'] == 'Zimbabwe']
# Out:
#       Country  Life expectancy      BMI
# 162  Zimbabwe             47.3  22.0266
